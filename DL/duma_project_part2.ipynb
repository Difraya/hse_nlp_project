# %% [markdown]
# # Duma hse nlp project. RNN and generate text.

# %%
# !mkdir /content/dumas_books
# Out:
# mkdir: cannot create directory ‘/content/dumas_books’: File exists

# %%
# !unrar x /content/Alexandre_Dumas.rar /content/dumas_books/
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
# Unexpected end of archive
#
# Extracting from /content/Alexandre_Dumas.rar
#
#
# Would you like to replace the existing file /content/dumas_books/Alexandre_Dumas-Marquise_De_Ganges.txt
# 125545 bytes, modified on 2025-04-11 18:38
# with a new one
# 125545 bytes, modified on 2025-04-11 18:38
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit A
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Total errors: 1

# %% [markdown]
# Let's begin with importing dependencies

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', None)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import nltk

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.model_selection import train_test_split
from collections import Counter
from typing import List

# %% [markdown]
# ## Choosing a literature and creating the vocabulary

# %%
import os
from nltk.tokenize import sent_tokenize

dumas_folder = '/content/dumas_books/'
dumas_file_paths = [os.path.join(dumas_folder, f) for f in os.listdir(dumas_folder) if f.endswith('.txt')]

# %%
dumas_file_paths
# Out:
# ['/content/dumas_books/Alexandre_Dumas-The_Man_In_The_Iron_Mask.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Companions_Of_Jehu.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Vicomte_De_Bragelonne.txt',
#  '/content/dumas_books/Alexandre_Dumas-Murat.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Black_Tulip.txt',
#  '/content/dumas_books/Alexandre_Dumas-Marquise_Brinvillier.txt',
#  '/content/dumas_books/Alexandre_Dumas-Vicomte_De_Bragelonne.txt',
#  '/content/dumas_books/Alexandre_Dumas-Ten_Years_Later.txt',
#  '/content/dumas_books/Alexandre_Dumas-Louise_De_La_Valliere.txt',
#  '/content/dumas_books/Alexandre_Dumas-Marquise_De_Ganges.txt',
#  '/content/dumas_books/Alexandre_Dumas-Vaninka.txt',
#  '/content/dumas_books/Alexandre_Dumas-Cenci.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Three_Musketeers.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Count_Of_Monte_Cristo.txt',
#  '/content/dumas_books/Alexandre_Dumas-Massacres_Of_The_South_(1551_1815).txt',
#  '/content/dumas_books/Alexandre_Dumas-Black_Tulip.txt',
#  '/content/dumas_books/Alexandre_Dumas-Celebrated_Crimes_Complete.txt',
#  '/content/dumas_books/Alexandre_Dumas-Ali_Pacha.txt',
#  '/content/dumas_books/Alexandre_Dumas-Derues.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Countess_Of_Saint_Geran.txt',
#  '/content/dumas_books/Alexandre_Dumas-The_Vicomte_De_Bragelonne;_Or_Ten_Years_Later.txt',
#  '/content/dumas_books/Alexandre_Dumas-Marguerite_De_Valois.txt',
#  '/content/dumas_books/Alexandre_Dumas-Urbain_Grandier.txt',
#  '/content/dumas_books/Alexandre_Dumas-Twenty_Years_After.txt',
#  '/content/dumas_books/Alexandre_Dumas-Martin_Guerre.txt']

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# Ok. Now we tokenize each book on sentences and put it in a dictionary

# %%
sentences_dumas = {}

for i, file_path in enumerate(dumas_file_paths, 1):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        text = file.read()
        sentences = sent_tokenize(text)
        variable_name = f'sentences_dumas_{i}'
        sentences_dumas[variable_name] = sentences

len(sentences_dumas)
# Out:
# 25

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# Now we want to do a single list with all 25 books sentences

# %%
sentences_lists = sentences_dumas.values()
all_sentences_duma = [sentence for sentences_list in sentences_lists for sentence in sentences_list]

# %%
len(all_sentences_duma)
# Out:
# 198249

# %% [markdown]
# Wow! We have 198249 sentences! Duma has done an enormous amount of work!

# %%
for sentence in all_sentences_duma[100:105]:
    print(sentence)
# Out:
# Even worse, Fouquet,
# desperate for money, is forced to sell the parliamentary position that
# renders him untouchable by any court proceedings.
# As part of her deal
# with Colbert, though, Chevreuse also obtains a secret audience with the
# queen-mother, where the two discuss a shocking secret--Louis XIV has a
# twin brother, long believed, however, to be dead.
# Meanwhile, in other quarters, De Wardes, Raoul's inveterate enemy, has
# returned from Calais, barely recovered from his wounds, and no sooner
# does he return than he begins again to insult people, particularly La
# Valliere, and this time the comte de Guiche is the one to challenge him.
# The duel leaves De Guiche horribly wounded, but enables Madame to use
# her influence to destroy De Wardes's standing at court.
# The _fetes_,
# however, come to an end, and the court returns to Paris.

# %%
sentences_duma_data = pd.DataFrame(all_sentences_duma)

# %%
random_rows = sentences_duma_data.sample(n=20)
print(random_rows)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0
# 131373                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     The magistrates assembled in the great hall of the Parliament, and the\nprisoner appeared before them.
# 173529                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       La Mole was radiant.
# 186540                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             cried the priest, with a laugh which made the dying\nman's hair stand on end; "I, absolve you?
# 65497                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Besides,\nthe only person with whom he could speak about her at his ease was\nSaint-Aignan, and thus Saint-Aignan had become an indispensable.
# 137860                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Distinguishing some of his old acquaintances, he called them to him, spoke familiarly of the days of their youth, of their games, their early friendships, and pointing to the young men, said, with tears in his eyes.</p>\n<p class="pnext">"The discord which has divided us for so many years has allowed children not born at the time of our dissension to grow into men.
# 156446                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The\nvoices ascended like vapors through the thick ceilings and the massive\nwalls, and rose in accusation against the author of this noise, as\ndoubtless their sighs and tears accused, in whispered tones, the author\nof their captivity.
# 61023                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      And what have you\nattributed my satisfaction to?”\n\n“That your business was going on very well; that your purchases of rice,\nprunes, raw sugar, dried apples, pears, and treacle were advantageous.
# 12133                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   As the events I want to relate occurred in 1799,\nand my heroes were executed in 1800, he will have covered that epoch,\nand can furnish me with the desired information.
# 109450                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Jeremie Ferrier, of Alais, who at the moment was regarded as the most eloquent preacher they had.
# 108727                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    A bed of dried\ngrass covered with goat-skins was placed in one corner.
# 99286                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            cried Valentine.
# 146686                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Although they had not been summoned, Manicamp and Malicorne had followed\nthe king and D'Artagnan.
# 59130                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            “Well,” said De Guiche, resigning himself, “lead me where you like, and\nask me what you please.”\n\n“It is impossible to be more agreeable than you are.” And then, after\na moment’s silence, Saint-Aignan continued, “I wish you to tell me\nsomething about a certain person in who you have interested yourself.”\n\n“And with whom you are in love?”\n\n“I will neither admit nor deny it.
# 198044                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           "</p>\n<p class="pnext">"Yes," she replied in a hollow voice.</p>\n<p class="pnext">"You will not contradict me?
# 70840                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      "Bah!"
# 25320                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     The Comte de la Fere, still faithful to his principles of loyalty, and royalty, one day developed before his son in the vaults of Saint Denis,--the Comte de la Fere, in the name of his son, had always declined them.
# 131494  Without mentioning local revolts which produced only short-lived\nstruggles and trifling changes, of administration, such as that of\nDjezzar Pacha, who refused to pay tribute because he thought himself\nimpregnable in his citadel of Saint-Jean-d'Acre, or that of\nPassevend-Oglou Pacha, who planted himself on the walls of Widdin as\ndefender of the Janissaries against the institution of the regular\nmilitia decreed by Sultan Selim at Stamboul, there were wider spread\nrebellions which attacked the constitution of the Turkish Empire and\ndiminished its extent; amongst them that of Czerni-Georges, which raised\nServia to the position of a free state; of Mahomet Ali, who made his\npachalik of Egypt into a kingdom; and finally that of the man whose,\nhistory we are about to narrate, Ali Tepeleni, Pacha of Janina, whose\nlong resistance to the suzerain power preceded and brought about the\nregeneration of Greece.
# 194678                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   And he offered\nhim his shoulder as another stay and support, so that his head almost\ntouched that of Mordaunt; and these two mortal enemies were in as close\nan embrace as if they had been brothers.
# 151220                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         "Most gratified, indeed, Monsieur le Surintendant, most gratified.
# 185212                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          cried D'Artagnan.

# %% [markdown]
# Now we choose sentences <= 32 words

# %%
all_sentences_duma_new = []
word_threshold = 32

for text in tqdm(all_sentences_duma):
    cleaned_text = text.replace('\\', '')
    all_sentences_duma_new.extend(
        [x.lower() for x in sent_tokenize(text.replace('\n', ''),\
                                          language='english') if len(word_tokenize(x)) < word_threshold])
# Out:
#   0%|          | 0/198249 [00:00<?, ?it/s]

# %%
all_sentences_duma_new[:5]
# Out:
# ["the man in the iron mask we'refamiliar with today is the last volume of the four-volume edition.",
#  "[not all the editions split them in the same manner, hence some of theconfusion...but wait...there's yet more reason for confusion.]",
#  "one thing that may be causing confusion is that the etext we have now,entitled ten years later, says it's the sequel to the three musketeers.",
#  "while this is technically true, there's another book, twenty yearsafter, that comes between.",
#  "also, the third book of thed'artagnan romances, while entitled the vicomte de bragelonne, has thesubtitle ten years later."]

# %%
print("Number of all sentences:", len(all_sentences_duma_new))
# Out:
# Number of all sentences: 154220

# %% [markdown]
# Now we will calculate the frequency of words in all the Duma books

# %%
words = Counter()
for sentence in tqdm(all_sentences_duma_new):
    for word in word_tokenize(sentence):
        words[word] += 1
# Out:
#   0%|          | 0/154220 [00:00<?, ?it/s]

# %%
len(words)
# Out:
# 72069

# %% [markdown]
# Wow! 72,000 words. What an impressive vocabulary!

# %%
first_30 = words.most_common(30)
# Print the first 30 key-value pairs
for word, count in first_30:
    print(word, count)
# Out:
# , 151258
# . 110932
# the 89129
# '' 84544
# `` 72010
# to 42546
# of 37570
# and 36577
# you 30969
# i 29932
# a 29239
# ? 24200
# he 22306
# ! 20925
# in 20733
# that 20005
# his 18018
# it 17587
# is 17186
# was 16811
# ; 16138
# said 14934
# not 14193
# with 11885
# at 11123
# my 10901
# have 10876
# but 10555
# me 10494
# for 10314

# %% [markdown]
# Interesting. We see many prepositions, articles, pronouns, and conjunctions, and no names...

# %% [markdown]
# Now we take 30k words (its enough!) of 72k words to exclude rare words from our vocabulary for training language models. And for faster training ofc!

# %%
vocab = set()
vocab_size = 30000
vocab = set(['<unk>', '<bos>', '<eos>', '<pad>'])
for word, cnt in words.most_common()[:vocab_size]:
  vocab.add(word)

# %%
assert '<unk>' in vocab
assert '<bos>' in vocab
assert '<eos>' in vocab
assert '<pad>' in vocab
assert len(vocab) == vocab_size + 4

# %%
print("All words in vocabulary:", len(vocab))
# Out:
# All words in vocabulary: 30004

# %%
word2ind = {char: i for i, char in enumerate(vocab)}
ind2word = {i: char for char, i in word2ind.items()}

# %% [markdown]
# ## Doing some preparations for models training

# %% [markdown]
# After that we code class WordDataset, add some padding to batch etc.

# %%
class WordDataset:
    def __init__(self, sentences):
        self.data = sentences
        self.unk_id = word2ind['<unk>']
        self.bos_id = word2ind['<bos>']
        self.eos_id = word2ind['<eos>']
        self.pad_id = word2ind['<pad>']

    def __getitem__(self, idx: int) -> List[int]:
        tokenized_sentence = [self.bos_id]
        tokenized_sentence += [word2ind.get(word, self.unk_id) for word in word_tokenize(self.data[idx])]
        tokenized_sentence += [self.eos_id]

        return tokenized_sentence

    def __len__(self) -> int:
        return len(self.data)

# %%
def collate_fn_with_padding(
    input_batch: List[List[int]], pad_id=word2ind['<pad>']) -> torch.Tensor:
    seq_lens = [len(x) for x in input_batch]
    max_seq_len = max(seq_lens)

    new_batch = []
    for sequence in input_batch:
        for _ in range(max_seq_len - len(sequence)):
            sequence.append(pad_id)
        new_batch.append(sequence)

    sequences = torch.LongTensor(new_batch).to(device)

    new_batch = {
        'input_ids': sequences[:,:-1],
        'target_ids': sequences[:,1:]
    }

    return new_batch

# %% [markdown]
# Now lets split out sentences to train, eval and test sentences. We will use test sentences to measure perplexity

# %%
train_sentences, eval_sentences = train_test_split(all_sentences_duma_new, test_size=0.2)
eval_sentences, test_sentences = train_test_split(eval_sentences, test_size=0.5)

train_dataset = WordDataset(train_sentences)
eval_dataset = WordDataset(eval_sentences)
test_dataset = WordDataset(test_sentences)

batch_size = 128

train_dataloader = DataLoader(
    train_dataset, collate_fn=collate_fn_with_padding, batch_size=batch_size)

eval_dataloader = DataLoader(
    eval_dataset, collate_fn=collate_fn_with_padding, batch_size=batch_size)

test_dataloader = DataLoader(
    test_dataset, collate_fn=collate_fn_with_padding, batch_size=batch_size)

# %%
def evaluate(model, criterion, dataloader) -> float:
    model.eval()
    perplexity = []
    with torch.no_grad():
        for batch in dataloader:
            logits = model(batch['input_ids']).flatten(start_dim=0, end_dim=1)
            loss = criterion(logits, batch['target_ids'].flatten())
            perplexity.append(torch.exp(loss).item())

    perplexity = sum(perplexity) / len(perplexity)

    return perplexity

# %% [markdown]
# Train cycle

# %%
def train_model(net, hidden_dim, vocab_size, epochs, train_dataloader,\
                eval_dataloader, lr=0.001, rnn=nn.RNN, num_layers=1):

    model = net(hidden_dim=hidden_dim, vocab_size=vocab_size, layer=rnn,\
                num_layers=num_layers).to(device)
    criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    losses_train = []
    perplexities_train = []
    losses_val = []
    perplexities_val = []

    for epoch in range(epochs):
        epoch_losses = []
        avg_loss_val = []
        perplexity = []
        perplexity_v = []
        model.train()
        for batch in tqdm(train_dataloader, desc=f'Training epoch {epoch}:'):
            optimizer.zero_grad()
            logits = model(batch['input_ids']).flatten(start_dim=0, end_dim=1)
            loss = criterion(logits, batch['target_ids'].flatten())
            loss.backward()
            optimizer.step()
            epoch_losses.append(loss.item())
            perplexity.append(torch.exp(loss).item())

        losses_train.append(sum(epoch_losses) / len(epoch_losses))
        perplexities_train.append(sum(perplexity) / len(perplexity))

        model.eval()
        with torch.no_grad():
            for batch in eval_dataloader:
                logits_val = model(batch['input_ids']).flatten(start_dim=0, end_dim=1)
                loss_val = criterion(logits_val, batch['target_ids'].flatten())
                avg_loss_val.append(loss_val.item())
                perplexity_v.append(torch.exp(loss_val).item())

        losses_val.append(sum(avg_loss_val) / len(avg_loss_val))
        perplexities_val.append(sum(perplexity_v) / len(perplexity_v))

    return (losses_train, losses_val, perplexities_train, perplexities_val, model)

# %% [markdown]
# Lets code LanguageModel class. We will use simple models.

# %%
class LanguageModel(nn.Module):
    def __init__(self, hidden_dim: int, vocab_size: int, layer=nn.RNN, num_layers=1):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, hidden_dim)
        self.rnn = layer(hidden_dim, hidden_dim, batch_first=True, num_layers=num_layers)
        self.linear = nn.Linear(hidden_dim, hidden_dim)
        self.projection = nn.Linear(hidden_dim, vocab_size)
        self.non_lin = nn.Tanh()
        self.dropout = nn.Dropout(p=0.1)

    def forward(self, input_batch: torch.Tensor) -> torch.Tensor:
        embeddings = self.embedding(input_batch)  # [batch_size, seq_len, hidden_dim]
        output, _ = self.rnn(embeddings)  # [batch_size, seq_len, hidden_dim]
        output = self.dropout(self.linear(self.non_lin(output)))  # [batch_size, seq_len, hidden_dim]
        projection = self.projection(self.non_lin(output))  # [batch_size, seq_len, vocab_size]

        return projection

# %%
def plot_all(losses_tr, losses_val, perplexities_tr, perplexities_val):
  fig, axes = plt.subplots(2, 2, figsize=(8, 8))

  # Losses
  axes[0, 0].plot(np.arange(len(losses_tr)), losses_tr)
  axes[0, 0].set_title('Train Losses')
  axes[0, 0].set_xlabel('Epoch')

  axes[0, 1].plot(np.arange(len(losses_val)), losses_val)
  axes[0, 1].set_title('Validation Losses')
  axes[0, 1].set_xlabel('Epoch')

  # Perplexity
  axes[1, 0].plot(np.arange(len(perplexities_tr)), perplexities_tr)
  axes[1, 0].set_title('Train Perplexity')
  axes[1, 0].set_xlabel('Epoch')

  axes[1, 1].plot(np.arange(len(perplexities_val)), perplexities_val)
  axes[1, 1].set_title('Validation Perplexity')
  axes[1, 1].set_xlabel('Epoch')

  plt.tight_layout()
  plt.show()

# %% [markdown]
# And in the end lets code function for sentence generating

# %%
def generate_sequence(model, starting_seq: str, max_seq_len: int = 256) -> str:
  device = 'cpu'
  model = model.to(device)
  input_ids = [word2ind['<bos>']] + [
    word2ind.get(char, word2ind['<unk>']) for char in word_tokenize(starting_seq)]
  input_ids = torch.LongTensor(input_ids).to(device)
  model.eval()
  with torch.no_grad():
    for i in range(max_seq_len):
      next_char_distribution = model(input_ids)[-1]
      next_char = next_char_distribution.squeeze().argmax()
      input_ids = torch.cat([input_ids, next_char.unsqueeze(0)])
      if next_char.item() == word2ind['<eos>']:
        break
  words = ' '.join([ind2word.get(idx.item(), '<unk>') for idx in input_ids])
  return words

# %% [markdown]
# ## Experiment 1. We use simple 1-layer RNN here

# %%
# %%time

losses_tr_1, losses_val_1, perplexities_tr_1, perplexities_val_1, model_1 =\
train_model(LanguageModel, hidden_dim=256, vocab_size=len(vocab), epochs=7,\
             train_dataloader=train_dataloader, eval_dataloader=eval_dataloader, lr=0.001, num_layers=1)
# Out:
# Training epoch 0::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 1::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 2::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 3::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 4::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 5::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 6::   0%|          | 0/964 [00:00<?, ?it/s]
# CPU times: user 9min 32s, sys: 2.29 s, total: 9min 34s
# Wall time: 9min 45s

# %%
plot_all(losses_tr_1, losses_val_1, perplexities_tr_1, perplexities_val_1)
criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
print('Perplexity on test: ', round(evaluate(model_1, criterion, test_dataloader)))
# Out:
# Perplexity on test:  60

# %% [markdown]
# 60 perplexity, not bad. Then i use this model with 'imdb dataset', the perplexity was around 100.

# %% [markdown]
# Lets save this model:

# %%
import joblib
from google.colab import files

class ModelWrapper:
    def __init__(self, model):
        self.model = model
        self.model.eval()

wrapper = ModelWrapper(model_1)

joblib_path = '/content/model_1_wrapper.joblib'
joblib.dump(wrapper, joblib_path)

files.download(joblib_path)

# %%
(
generate_sequence(model_1, starting_seq='young d’artagnan arrived in paris with nothing but a sword and a dream to '),
generate_sequence(model_1, starting_seq='athos is a man who '),
generate_sequence(model_1, starting_seq='aramis believed that '),
generate_sequence(model_1, starting_seq='milady de winter, with a faint smile on her lips and a dagger in her sleeve, was ready to '),
generate_sequence(model_1, starting_seq='monte cristo knew that ')
)
# Out:
# ('<bos> young d ’ artagnan arrived in paris with nothing but a sword and a dream to the king . <eos>',
#  "<bos> athos is a man who has been stolen from the king . '' <eos>",
#  '<bos> aramis believed that he was not mistaken . <eos>',
#  '<bos> milady de winter , with a faint smile on her lips and a dagger in her sleeve , was ready to be <unk> . <eos>',
#  '<bos> monte cristo knew that he was not mistaken . <eos>')

# %% [markdown]
# Now lets generate questions

# %%
(
generate_sequence(model_1, starting_seq='is d’artagnan going to challenge him to a duel, or '),
generate_sequence(model_1, starting_seq='was athos ever able to forget milady, or '),
generate_sequence(model_1, starting_seq='does the count of monte cristo truly believe in justice, or '),
generate_sequence(model_1, starting_seq='who poisoned the wine at the cardinal’s banquet, and '),
generate_sequence(model_1, starting_seq='should edmond dantès reveal his true identity now, or ')
)
# Out:
# ('<bos> is d ’ artagnan going to challenge him to a duel , or rather , and i will not be able to do . <eos>',
#  '<bos> was athos ever able to forget milady , or rather the <unk> . <eos>',
#  "<bos> does the count of monte cristo truly believe in justice , or rather ? '' <eos>",
#  "<bos> who poisoned the wine at the cardinal ’ s banquet , and i will not ? '' <eos>",
#  '<bos> should edmond <unk> reveal his true identity now , or rather the <unk> . <eos>')

# %% [markdown]
# We can see a little problem with "unks".

# %% [markdown]
# ### Experiment 2. Lets take LSTM layer

# %%
# %%time

losses_tr_exp_2, losses_val_exp_2, perplexities_tr_exp_2, perplexities_val_exp_2, model_2 =\
train_model(LanguageModel, hidden_dim=256, vocab_size=len(vocab), epochs=7,\
            train_dataloader=train_dataloader, eval_dataloader=eval_dataloader,\
            lr=0.001, rnn=nn.LSTM, num_layers=1)
# Out:
# Training epoch 0::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 1::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 2::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 3::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 4::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 5::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 6::   0%|          | 0/964 [00:00<?, ?it/s]
# CPU times: user 9min 49s, sys: 2.13 s, total: 9min 51s
# Wall time: 9min 57s

# %%
plot_all(losses_tr_exp_2, losses_val_exp_2, perplexities_tr_exp_2, perplexities_val_exp_2)
criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
print('Perplexity on test: ', round(evaluate(model_2, criterion, test_dataloader)))
# Out:
# Perplexity on test:  54

# %% [markdown]
# 55. Wow. It's much better!

# %%
(
generate_sequence(model_2, starting_seq='young d’artagnan arrived in paris with nothing but a sword and a dream to '),
generate_sequence(model_2, starting_seq='athos is a man who '),
generate_sequence(model_2, starting_seq='aramis believed that '),
generate_sequence(model_2, starting_seq='milady de winter, with a faint smile on her lips and a dagger in her sleeve, was ready to '),
generate_sequence(model_2, starting_seq='monte cristo knew that ')
)
# Out:
# ('<bos> young d ’ artagnan arrived in paris with nothing but a sword and a dream to her . <eos>',
#  "<bos> athos is a man who has been stolen from the <unk> of the king . '' <eos>",
#  '<bos> aramis believed that he was not mistaken , but he was not mistaken . <eos>',
#  '<bos> milady de winter , with a faint smile on her lips and a dagger in her sleeve , was ready to be able to see her . <eos>',
#  '<bos> monte cristo knew that he was not mistaken , but he was not mistaken . <eos>')

# %%
(
generate_sequence(model_2, starting_seq='is d’artagnan going to challenge him to a duel, or '),
generate_sequence(model_2, starting_seq='was athos ever able to forget milady, or '),
generate_sequence(model_2, starting_seq='does the count of monte cristo truly believe in justice, or '),
generate_sequence(model_2, starting_seq='who poisoned the wine at the cardinal’s banquet, and '),
generate_sequence(model_2, starting_seq='should edmond dantès reveal his true identity now, or ')
)
# Out:
# ('<bos> is d ’ artagnan going to challenge him to a duel , or i ? <eos>',
#  '<bos> was athos ever able to forget milady , or rather the king , who had not seen him . <eos>',
#  "<bos> does the count of monte cristo truly believe in justice , or rather i am going to do so ? '' <eos>",
#  '<bos> who poisoned the wine at the cardinal ’ s banquet , and the <unk> of the <unk> of the king of navarre was not a man to have been able to have been able to resign him . <eos>',
#  '<bos> should edmond <unk> reveal his true identity now , or rather the <unk> to the king . <eos>')

# %%
wrapper = ModelWrapper(model_2)

joblib_path = '/content/model_2_wrapper.joblib'
joblib.dump(wrapper, joblib_path)

files.download(joblib_path)

# %% [markdown]
# **Further experiments will be continued by my colleague Yulia.**

# %% [markdown]
# ### Experiment 3. 3 layers LSTM

# %%
# %%time

losses_tr_exp_3, losses_val_exp_3, perplexities_tr_exp_3, perplexities_val_exp_3, model_3 =\
train_model(LanguageModel, hidden_dim=256, vocab_size=len(vocab), epochs=7,\
             train_dataloader=train_dataloader, eval_dataloader=eval_dataloader, lr=0.001, rnn=nn.LSTM, num_layers=3)
# Out:
# Training epoch 0::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 1::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 2::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 3::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 4::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 5::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 6::   0%|          | 0/964 [00:00<?, ?it/s]
# CPU times: user 10min 56s, sys: 2.1 s, total: 10min 58s
# Wall time: 11min 6s

# %%
plot_all(losses_tr_exp_3, losses_val_exp_3, perplexities_tr_exp_3, perplexities_val_exp_3)
criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
print('Perplexity on test: ', round(evaluate(model_3, criterion, test_dataloader)))
# Out:
# Perplexity on test:  63

# %% [markdown]
# Перплексити 63 - многовато, но лучше случайного угадывания, учитывая что у нас 30к слов

# %%
(
generate_sequence(model_3, starting_seq='young d’artagnan arrived in paris with nothing but a sword and a dream to '),
generate_sequence(model_3, starting_seq='athos is a man who '),
generate_sequence(model_3, starting_seq='aramis believed that '),
generate_sequence(model_3, starting_seq='milady de winter, with a faint smile on her lips and a dagger in her sleeve, was ready to '),
generate_sequence(model_3, starting_seq='monte cristo knew that ')
)
# Out:
# ('<bos> young d ’ artagnan arrived in paris with nothing but a sword and a dream to be <unk> . <eos>',
#  '<bos> athos is a man who has been <unk> , and i will not be sure to be a <unk> . <eos>',
#  '<bos> aramis believed that he was not mistaken , and he was not a man who has <unk> . <eos>',
#  '<bos> milady de winter , with a faint smile on her lips and a dagger in her sleeve , was ready to be seen . <eos>',
#  '<bos> monte cristo knew that he was not a man who was not a man who was not a man . <eos>')

# %%
(
generate_sequence(model_3, starting_seq='is d’artagnan going to challenge him to a duel, or '),
generate_sequence(model_3, starting_seq='was athos ever able to forget milady, or '),
generate_sequence(model_3, starting_seq='does the count of monte cristo truly believe in justice, or '),
generate_sequence(model_3, starting_seq='who poisoned the wine at the cardinal’s banquet, and '),
generate_sequence(model_3, starting_seq='should edmond dantès reveal his true identity now, or ')
)
# Out:
# ("<bos> is d ’ artagnan going to challenge him to a duel , or rather the king 's household ? <eos>",
#  "<bos> was athos ever able to forget milady , or rather the king 's <unk> , and the <unk> the <unk> . <eos>",
#  "<bos> does the count of monte cristo truly believe in justice , or rather that i should have been able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be a <unk> . '' <eos>",
#  "<bos> who poisoned the wine at the cardinal ’ s banquet , and the king 's <unk> ? <eos>",
#  "<bos> should edmond <unk> reveal his true identity now , or rather the king 's <unk> . <eos>")

# %% [markdown]
# 1. <.unk.> - у модели проблема с кодированием некоторыми символами?
# 2. есть проблема с повторами
# Во всем остальном генерация кажется адекватной, стиль похож на Дюма

# %%
wrapper = ModelWrapper(model_3)

joblib_path = '/content/model_3_wrapper.joblib'
joblib.dump(wrapper, joblib_path)

files.download(joblib_path)

# %% [markdown]
# ### Experiment 4. No dropout, hidden_dim=512, 3 layers

# %%
class LanguageModel_no_drop(nn.Module):
    def __init__(self, hidden_dim: int, vocab_size: int, layer=nn.RNN, num_layers=1):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, hidden_dim)
        self.rnn = layer(hidden_dim, hidden_dim, batch_first=True, num_layers=num_layers)
        self.linear = nn.Linear(hidden_dim, hidden_dim)
        self.projection = nn.Linear(hidden_dim, vocab_size)
        self.non_lin = nn.Tanh()

    def forward(self, input_batch: torch.Tensor) -> torch.Tensor:
        embeddings = self.embedding(input_batch)  # [batch_size, seq_len, hidden_dim]
        output, _ = self.rnn(embeddings)  # [batch_size, seq_len, hidden_dim]
        output = self.linear(self.non_lin(output))  # [batch_size, seq_len, hidden_dim]
        projection = self.projection(self.non_lin(output))  # [batch_size, seq_len, vocab_size]

        return projection

# %% [markdown]
# Попробую увеличить эпохи

# %%
# %%time

losses_tr_exp_4, losses_val_exp_4, perplexities_tr_exp_4, perplexities_val_exp_4, model_4 =\
train_model(LanguageModel_no_drop, hidden_dim=512, vocab_size=len(vocab), epochs=9,\
             train_dataloader=train_dataloader, eval_dataloader=eval_dataloader, lr=0.001, rnn=nn.LSTM, num_layers=3)
# Out:
# Training epoch 0::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 1::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 2::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 3::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 4::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 5::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 6::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 7::   0%|          | 0/964 [00:00<?, ?it/s]
# Training epoch 8::   0%|          | 0/964 [00:00<?, ?it/s]
# CPU times: user 27min 1s, sys: 5.31 s, total: 27min 6s
# Wall time: 27min 22s

# %%
plot_all(losses_tr_exp_4, losses_val_exp_4, perplexities_tr_exp_4, perplexities_val_exp_4)
criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
print('Perplexity on test: ', round(evaluate(model_4, criterion, test_dataloader)))
# Out:
# Perplexity on test:  63

# %%
# plot_all(losses_tr_exp_4, losses_val_exp_4, perplexities_tr_exp_4, perplexities_val_exp_4)
# criterion = nn.CrossEntropyLoss(ignore_index=word2ind['<pad>'])
# print('Perplexity on test: ', round(evaluate(model_4, criterion, test_dataloader)))
# Out:
# Perplexity on test:  97

# %% [markdown]
# Перплексити заметно ухудшился, возможно будет больше спонтанных генераций

# %%
(
generate_sequence(model_4, starting_seq='young d’artagnan arrived in paris with nothing but a sword and a dream to '),
generate_sequence(model_4, starting_seq='athos is a man who '),
generate_sequence(model_4, starting_seq='aramis believed that '),
generate_sequence(model_4, starting_seq='milady de winter, with a faint smile on her lips and a dagger in her sleeve, was ready to '),
generate_sequence(model_4, starting_seq='monte cristo knew that ')
)
# Out:
# ('<bos> young d ’ artagnan arrived in paris with nothing but a sword and a dream to be taken . <eos>',
#  '<bos> athos is a man who has <unk> to be a moralist . <eos>',
#  '<bos> aramis believed that he was not mistaken , but he was not mistaken . <eos>',
#  '<bos> milady de winter , with a faint smile on her lips and a dagger in her sleeve , was ready to be pitied . <eos>',
#  '<bos> monte cristo knew that he couldkeep <unk> . <eos>')

# %%
(
generate_sequence(model_4, starting_seq='is d’artagnan going to challenge him to a duel, or '),
generate_sequence(model_4, starting_seq='was athos ever able to forget milady, or '),
generate_sequence(model_4, starting_seq='does the count of monte cristo truly believe in justice, or '),
generate_sequence(model_4, starting_seq='who poisoned the wine at the cardinal’s banquet, and '),
generate_sequence(model_4, starting_seq='should edmond dantès reveal his true identity now, or ')
)
# Out:
# ('<bos> is d ’ artagnan going to challenge him to a duel , or rather the king ? <eos>',
#  '<bos> was athos ever able to forget milady , or rather that he was not dead ? <eos>',
#  '<bos> does the count of monte cristo truly believe in justice , or rather that he was not dead ? <eos>',
#  '<bos> who poisoned the wine at the cardinal ’ s banquet , and <unk> to be pitied , and the king of navarre was a materialist . <eos>',
#  '<bos> should edmond <unk> reveal his true identity now , or rather <unk> , the king of navarre , who was <unk> . <eos>')

# %% [markdown]
# 1. <.unk.> - этой проблемы стало явно больше
# 2. Но предложения стали лучше

# %%
wrapper = ModelWrapper(model_4)

joblib_path = '/content/model_4_wrapper.joblib'
joblib.dump(wrapper, joblib_path)

files.download(joblib_path)

# %% [markdown]
# ## Excercise for fun

# %%
sentences_duma_data.columns = ['sentences']
sentences_duma_data.head(2)
# Out:
#                                                                                                                                                                                                                                         sentences
# 0  THE MAN IN THE IRON MASK\n\nby Alexandre Dumas\n\n\n\n***\n\nThe Vicomte de Bragelonne is the final volume of D'Artagnan Romances:\nit is usually split into three or four parts, and the final portion\nis entitled The Man in the Iron Mask.
# 1                                                                                                                                              The Man in the Iron Mask we're\nfamiliar with today is the last volume of the four-volume edition.

# %% [markdown]
# функция, которая будет проверять, что длина списка sentences не меньше 6. Если это так, она случайным образом возьмёт от 3 до 5 первых слов из оригинального предложения и сгенерирует новое предложение.

# %%
import random

def generate_random_sequence(model, sentences_df):
    # Select a random sentence from the dataframe with a length of 6 or more words
    candidate_sentences = sentences_df[sentences_df['sentences'].str.split().apply(len) >= 6]
    random_sentence = random.choice(candidate_sentences['sentences'])

    # Convert the sentence to lowercase
    random_sentence = random_sentence.lower()

    # Split the sentence into words
    words = random_sentence.split()

    # Select the first 3-5 words from the sentence
    num_words = random.randint(3, min(5, len(words)))
    selected_words = words[:num_words]

    # Construct the starting sequence by joining the selected words
    starting_sequence = ' '.join(selected_words)

    # Generate a sequence using the model and the starting sequence
    generated_sequence = generate_sequence(model, starting_seq=starting_sequence)

    # Remove special tokens from the generated sequence
    generated_sequence = generated_sequence.replace('<bos>', '').replace('<eos>', '').replace('<unk>', '')

    return random_sentence, generated_sequence

# %%
generate_random_sequence(model_1, sentences_duma_data)
# Out:
# ('"now, then," the young man coolly remarked, whilst the crowd was rushing\ninto the principal gate of the town-hall, "it seems the question will be\ndiscussed indoors, captain.',
#  " `` now , then , '' the young man , `` you are not a good deal , and i will not be able to do . ")

# %%
generate_random_sequence(model_2, sentences_duma_data)
# Out:
# ("for a long time all search was in vain, but one day the wife of a miller\nnamed semenil came into town ostensibly to buy provisions, but really to\ndenounce them as being concealed, with two other camisards, in her\nhusband's house.",
#  ' for a long time he had been able to see him , and he was obliged to  . ')

# %%
generate_random_sequence(model_3, sentences_duma_data)
# Out:
# ('cornelius wrote:--\n\n"my dear godson,--\n\n"burn the parcel which i have intrusted to you.',
#  " cornelius wrote : -- `` my dear friend , i will not say that i am not a man . '' ")

# %%
generate_random_sequence(model_3, sentences_duma_data)
# Out:
# ('i am glad he will see belle-isle,\nhe is so good a judge of fortifications."',
#  ' i am glad he was , and i am not sure of it . ')

# %%
original_sentence_1, generated_sequence_1 = generate_random_sequence(model_1, sentences_duma_data)
original_sentence_2, generated_sequence_2 = generate_random_sequence(model_2, sentences_duma_data)
original_sentence_3, generated_sequence_3 = generate_random_sequence(model_3, sentences_duma_data)
original_sentence_4, generated_sequence_4 = generate_random_sequence(model_4, sentences_duma_data)

# %%
print("Model_1. Original Sentence:", original_sentence_1, "Generated Sequence:", generated_sequence_1, sep='\n')
print("Model_2. Original Sentence:", original_sentence_2, "Generated Sequence:", generated_sequence_2, sep='\n')
print("Model_3. Original Sentence:", original_sentence_3, "Generated Sequence:", generated_sequence_3, sep='\n')
print("Model_4. Original Sentence:", original_sentence_4, "Generated Sequence:", generated_sequence_4, sep='\n')
# Out:
# Model_1. Original Sentence:
# the orientals are stronger than we are in
# cases of conscience, and, very prudently, have no hell--that is the
# point."
# Generated Sequence:
#  the orientals are stronger than that , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and the  , and
# Model_2. Original Sentence:
# my dear rosa, i have been dreaming all night, in the
# first place of you," (rosa made a sign of incredulity,) "and then of
# what we must do."
# Generated Sequence:
#  my dear rosa , that i should have been able to be able to take care of it .
# Model_3. Original Sentence:
# "indeed, these people must certainly be prompted by a most violent
# indignation," said the young man, with the same impassible tone which
# he had preserved all along.
# Generated Sequence:
#  `` indeed , these people must certainly be a little  . ''
# Model_4. Original Sentence:
# the pioneers and laborers were, in the army of this man, a body full of
# ideas and zeal, because their commander treated them like soldiers, knew
# how to render their work glorious, and never allowed them to be killed
# if he could help it.
# Generated Sequence:
#  the pioneers and the king , as he had left , was  , and the  to be burnt .

# %% [markdown]
# Честно говоря тут просто попытка, тк сгенерированные предложения бредовые. Возможно из-за того, что мы взяли 30к слов самых популярных из 72к.
